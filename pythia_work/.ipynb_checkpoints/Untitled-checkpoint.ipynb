# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy as sc
import csv

# %%
with open('tomography_data.csv', 'r') as file:
    print(file)
# Out:
# <_io.TextIOWrapper name='tomography_data.csv' mode='r' encoding='UTF-8'>

# %% [markdown]
# Hay varios eventos en los cuales se produce más de un higgs, de los cuales salen pares $\tau$/$\overline{\tau}$. Debemos seleccionar sólo los higgs que producieron este par:

# %%
print(data)
